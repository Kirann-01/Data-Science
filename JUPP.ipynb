# %% [markdown]
# <H1> MY JUPYTER NOTEBOOK </H1>

# %% [markdown]
# <H2>H B KIRAN GOWDA </H2>
#
# data scientist

# %% [markdown]
# I am interested in data science as the use of data excites me and makes me kken to learn more about it

# %% [markdown]
# <H3>The code prints sum of 2 numbers</H3>

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# 1) hello world
# 2)python
# 3)kernels
